# %%
#import library
import pandas as pd
from google.cloud import bigquery

# %%
#read data from BQ table kabupaten data
client = bigquery.Client()
query = """
SELECT * 
FROM `ai4indonesia.geoplan_dev.ai4_data_pinjaman_kab_rank` 

"""
query_job = client.query(query)
results = query_job.result()

df_kab_pinjaman = results.to_dataframe()

df_kab_pinjaman.head()
# Out:
#                prov           kab_name  kab_id  \
# 0  Kalimantan Timur        kutai barat    6402
# 1  Kalimantan Timur  kutai kartanegara    6403
# 2  Kalimantan Timur              berau    6405
# 3  Kalimantan Barat     kota pontianak    6171
# 4  Kalimantan Barat     kota pontianak    6171
#
#                   jenis_sektor_ekonomi  \
# 0  Pinjaman Berdasarkan Lapangan Usaha
# 1  Pinjaman Berdasarkan Lapangan Usaha
# 2  Pinjaman Berdasarkan Lapangan Usaha
# 3  Pinjaman Berdasarkan Lapangan Usaha
# 4  Pinjaman Berdasarkan Lapangan Usaha
#
#                                            jenis_kpi   real_2017   real_2018  \
# 0                                       Jasa Lainnya   651893.99  1296717.26
# 1                         Jasa Keuangan Dan Asuransi    34914.50    11030.62
# 2                        Pertambangan dan Penggalian   860125.23  2384398.91
# 3               Penyediaan Akomodasi Dan Makan Minum   380300.88   451010.94
# ...

# %%
#read data from BQ table kabupaten data
client = bigquery.Client()
query = """
SELECT * 
FROM `ai4indonesia.geoplan_dev.ai4_data_simpanan_kab_rank` 

"""
query_job = client.query(query)
results = query_job.result()

df_kab_simpanan = results.to_dataframe()

df_kab_simpanan.head()
# Out:
#                  prov           kab_name  kab_id jenis_simpanan jenis_kpi  \
# 0    Kalimantan Utara       kota tarakan    6571       Tabungan   Nominal
# 1    Kalimantan Barat     kota pontianak    6171       Tabungan   Nominal
# 2   Kalimantan Tengah  kota palangkaraya    6271       Tabungan   Nominal
# 3    Kalimantan Timur     kota samarinda    6472       Tabungan   Nominal
# 4  Kalimantan Selatan   kota banjarmasin    6371       Tabungan   Nominal
#
#      real_2018    real_2019    real_2020    real_2021    real_2022  ...  \
# 0   3236270.95   3446473.85   3725050.23   4153474.58   4516077.32  ...
# 1  13768293.88  14176141.56  15636562.28  17466906.94  19076608.21  ...
# 2   3990201.77   4298120.47   4828359.72   5051783.29   5087147.88  ...
# 3  14863404.79  15615151.84  17017801.96  18696933.25  20887799.79  ...
# 4  12094292.08  12901823.77  13288590.06  14515580.80  15061198.09  ...
#
#    rank_real_2023  rank_growth_2023  rank_pred_2024  rank_growth_2024  \
# ...

# %%
#read data from BQ table kabupaten data
client = bigquery.Client()
query = """
SELECT * 
FROM `ai4indonesia.geoplan_dev.ai4_data_pinjaman_umkm_kab_rank` 

"""
query_job = client.query(query)
results = query_job.result()

df_kab_umkm = results.to_dataframe()

df_kab_umkm.head()
# Out:
#    kab_id kab_name              prov                 jenis_sektor_ekonomi  \
# 0    6401    paser  kalimantan timur  Pinjaman Berdasarkan Lapangan Usaha
# 1    6401    paser  kalimantan timur  Pinjaman Berdasarkan Lapangan Usaha
# 2    6401    paser  kalimantan timur  Pinjaman Berdasarkan Lapangan Usaha
# 3    6401    paser  kalimantan timur  Pinjaman Berdasarkan Lapangan Usaha
# 4    6401    paser  kalimantan timur  Pinjaman Berdasarkan Lapangan Usaha
#
#                                            jenis_kpi  real_2017  real_2018  \
# 0  Perdagangan Besar Dan Eceran, Reparasi Mobil D...  408925.00  415222.12
# 1                                        Real Estate    3034.32    6630.27
# 2                        Pertambangan dan Penggalian      63.50     506.13
# 3                Jasa Kesehatan Dan Kegiatan Lainnya     724.87     321.81
# 4                          Pengadaan Listrik Dan Gas    3130.35      45.18
#
# ...

# %%
#read data from BQ table kecamatan data
client = bigquery.Client()
query = """
SELECT * 
FROM `ai4indonesia.geoplan_dev.ai4_data_pinjaman_kec_rank_v3` 

"""
query_job = client.query(query)
results = query_job.result()

df_kec_pinjaman = results.to_dataframe()

df_kec_pinjaman.head()
# Out:
#           prov_name kab_name  kab_id kec_name   kec_id          id_nama  \
# 0  Kalimantan Barat   sambas    6101  selakau  6101010  6101010-SELAKAU
# 1  Kalimantan Barat   sambas    6101  selakau  6101010  6101010-SELAKAU
# 2  Kalimantan Barat   sambas    6101  selakau  6101010  6101010-SELAKAU
# 3  Kalimantan Barat   sambas    6101  selakau  6101010  6101010-SELAKAU
# 4  Kalimantan Barat   sambas    6101  selakau  6101010  6101010-SELAKAU
#
#                          jenis_simpanan  \
# 0   Pinjaman Berdasarkan Lapangan Usaha
# 1   Pinjaman Berdasarkan Lapangan Usaha
# 2   Pinjaman Berdasarkan Lapangan Usaha
# 3   Pinjaman Berdasarkan Lapangan Usaha
# 4  Pinjaman Kepada Bukan Lapangan Usaha
#
#                                            jenis_kpi     pred_2018  \
# 0                                         Konstruksi    777.067670
# 1                                        Real Estate    264.846021
# 2                         Jasa Keuangan Dan Asuransi   2469.937087
# ...

# %%
#read data from BQ table kecamatan data
client = bigquery.Client()
query = """
SELECT * 
FROM `ai4indonesia.geoplan_dev.ai4_data_simpanan_kec_rank_v3` 

"""
query_job = client.query(query)
results = query_job.result()

df_kec_simpanan = results.to_dataframe()

df_kec_simpanan.head()
# Out:
#           prov_name kab_name  kab_id       kec_name   kec_id  \
# 0  Kalimantan Barat   sambas    6101        selakau  6101010
# 1  Kalimantan Barat   sambas    6101  selakau timur  6101011
# 2  Kalimantan Barat   sambas    6101      pemangkat  6101020
# 3  Kalimantan Barat   sambas    6101       semparuk  6101021
# 4  Kalimantan Barat   sambas    6101       salatiga  6101022
#
#                  id_nama jenis_kpi jenis_simpanan      pred_2018  \
# 0        6101010-SELAKAU   Nominal       Tabungan  119188.372726
# 1  6101011-SELAKAU TIMUR   Nominal       Tabungan   87592.748437
# 2      6101020-PEMANGKAT   Nominal       Tabungan  154510.610638
# 3       6101021-SEMPARUK   Nominal       Tabungan  111814.826727
# 4       6101022-SALATIGA   Nominal       Tabungan   94967.870743
#
#        pred_2019  ...  rank_pred_2023_kab  rank_growth_2023_kab  \
# 0  118027.057858  ...                   6                    14
# 1  112101.132506  ...                  19                     2
# ...

# %%
#read data from BQ table kecamatan data
client = bigquery.Client()
query = """
SELECT * 
FROM `ai4indonesia.geoplan_dev.ai4_data_pinjaman_umkm_kec_rank_v3` 

"""
query_job = client.query(query)
results = query_job.result()

df_kec_umkm = results.to_dataframe()

df_kec_umkm.head()
# Out:
#           prov_name kab_name  kab_id kec_name   kec_id          id_nama  \
# 0  Kalimantan Barat   sambas    6101  selakau  6101010  6101010-SELAKAU
# 1  Kalimantan Barat   sambas    6101  selakau  6101010  6101010-SELAKAU
# 2  Kalimantan Barat   sambas    6101  selakau  6101010  6101010-SELAKAU
# 3  Kalimantan Barat   sambas    6101  selakau  6101010  6101010-SELAKAU
# 4  Kalimantan Barat   sambas    6101  selakau  6101010  6101010-SELAKAU
#
#                         jenis_simpanan                   jenis_kpi  \
# 0  Pinjaman Berdasarkan Lapangan Usaha  Jasa Keuangan Dan Asuransi
# 1  Pinjaman Berdasarkan Lapangan Usaha   Pengadaan Listrik Dan Gas
# 2                       kelompok usaha                       Kecil
# 3  Pinjaman Berdasarkan Lapangan Usaha                 Real Estate
# 4  Pinjaman Berdasarkan Lapangan Usaha         Industri Pengolahan
#
#       pred_2018     pred_2019  ...  rank_pred_2023_kab  rank_growth_2023_kab  \
# ...

# %%
#list column kab
df_kab_simpanan.columns
# Out:
# Index(['prov', 'kab_name', 'kab_id', 'jenis_simpanan', 'jenis_kpi',
#        'real_2018', 'real_2019', 'real_2020', 'real_2021', 'real_2022',
#        'real_2023', 'pred_2024', 'pred_2025', 'pred_2026', 'pred_2027',
#        'pred_2028', 'rank_real_2023', 'rank_growth_2023', 'rank_pred_2024',
#        'rank_growth_2024', 'rank_pred_2028', 'rank_growth_2028',
#        'rank_potensi_2023', 'rank_potensi_2024', 'rank_potensi_2025',
#        'rank_potensi_2028'],
#       dtype='object')

# %%
#list column kec
df_kec_simpanan.columns
# Out:
# Index(['prov_name', 'kab_name', 'kab_id', 'kec_name', 'kec_id', 'id_nama',
#        'jenis_kpi', 'jenis_simpanan', 'pred_2018', 'pred_2019', 'pred_2020',
#        'pred_2021', 'pred_2022', 'pred_2023', 'pred_2024', 'pred_2025',
#        'pred_2026', 'pred_2027', 'pred_2028', 'rank_pred_2023_prov',
#        'rank_growth_2023_prov', 'rank_pred_2024_prov', 'rank_growth_2024_prov',
#        'rank_pred_2028_prov', 'rank_growth_2028_prov', 'rank_pred_2023_kab',
#        'rank_growth_2023_kab', 'rank_pred_2024_kab', 'rank_growth_2024_kab',
#        'rank_pred_2028_kab', 'rank_growth_2028_kab', 'rank_potensi_2023',
#        'rank_potensi_2024', 'rank_potensi_2025', 'rank_potensi_2028'],
#       dtype='object')

# %%
#exclude "Lainnya"
df_kab_pinjaman = df_kab_pinjaman[~df_kab_pinjaman.jenis_kpi.isin(['Jasa Lainnya', 'Lainnya'])]
df_kec_pinjaman = df_kec_pinjaman[~df_kec_pinjaman.jenis_kpi.isin(['Jasa Lainnya', 'Lainnya'])]

#exclude "Lainnya"
df_kab_umkm = df_kab_umkm[~df_kab_umkm.jenis_kpi.isin(['Jasa Lainnya', 'Lainnya'])]
df_kec_umkm = df_kec_umkm[~df_kec_umkm.jenis_kpi.isin(['Jasa Lainnya', 'Lainnya'])]

# %%
#Kota Kabupaten Only
import sys
for x in df_kab_pinjaman['kab_name'].unique():
    print(x)
    with open('dict/narasi_kab/output_'+x+'_v4.txt', 'w') as f:
        df_twr = df_kab_pinjaman.loc[df_kab_pinjaman['kab_name'] == x].copy()
        df_twr2 = df_kab_simpanan.loc[df_kab_simpanan['kab_name'] == x].copy()
        df_twr3 = df_kab_umkm.loc[df_kab_umkm['kab_name'] == x].copy()
        print(x+" adalah kabupaten di provinsi ", end="", file = f)
        print(df_twr['prov'].unique()[0]+".", end=" ", file = f)
        
        min_2023 = df_twr2['rank_potensi_2023'].min()
        df_rank2_2023 = df_twr2.loc[df_twr2['rank_potensi_2023'] == min_2023].copy()
        min_2024 = df_twr2['rank_potensi_2024'].min()
        df_rank2_2024 = df_twr2.loc[df_twr2['rank_potensi_2024'] == min_2024].copy()
        min_2028 = df_twr2['rank_potensi_2028'].min()
        df_rank2_2028 = df_twr2.loc[df_twr2['rank_potensi_2028'] == min_2028].copy()
        print("Potensi simpanan di kabupaten "+x+" pada tahun 2023 adalah "+df_rank2_2023['jenis_simpanan'].values[0]+", "+\
              "menduduki peringkat ke-"+str(min_2023)+" antar provinsi "+df_twr['prov'].unique()[0]+".",\
                end=" ", file = f)
        
        
        min_2023 = df_twr['rank_potensi_2023'].min()
        df_rank1_2023 = df_twr.loc[df_twr['rank_potensi_2023'] == min_2023].copy()
        min_2024 = df_twr['rank_potensi_2024'].min()
        df_rank1_2024 = df_twr.loc[df_twr['rank_potensi_2024'] == min_2024].copy()
        min_2028 = df_twr['rank_potensi_2028'].min()
        df_rank1_2028 = df_twr.loc[df_twr['rank_potensi_2028'] == min_2028].copy()
                
        print("Potensi sektor ekonomi terbaik di kabupaten "+x+" pada tahun 2023 adalah "+df_rank1_2023['jenis_kpi'].values[0]+", "+\
              "menduduki peringkat ke-"+str(min_2023)+" antar provinsi "+df_twr['prov'].unique()[0]+"",\
                end=",", file = f)
        print(" prediksi tahun 2024 adalah "+df_rank1_2024['jenis_kpi'].values[0]+", "+\
                "menduduki peringkat ke-"+str(min_2024)+" antar provinsi "+df_twr['prov'].unique()[0]+"",\
                end=",", file = f)
        print(" dan prediksi pada tahun 2028 adalah "+df_rank1_2028['jenis_kpi'].values[0]+", "+\
                "menduduki peringkat ke-"+str(min_2028)+" antar provinsi "+df_twr['prov'].unique()[0]+".",\
                end=" ", file = f)
        
        min_2023 = df_twr3['rank_potensi_2023'].min()
        df_rank3_2023 = df_twr3.loc[df_twr3['rank_potensi_2023'] == min_2023].copy()
        min_2024 = df_twr3['rank_potensi_2024'].min()
        df_rank3_2024 = df_twr3.loc[df_twr3['rank_potensi_2024'] == min_2024].copy()
        min_2028 = df_twr3['rank_potensi_2028'].min()
        df_rank3_2028 = df_twr3.loc[df_twr3['rank_potensi_2028'] == min_2028].copy()
                
        print("Potensi sektor UMKM terbaik di kabupaten "+x+" pada tahun 2023 adalah "+df_rank3_2023['jenis_kpi'].values[0]+", "+\
              "menduduki peringkat ke-"+str(min_2023)+" antar provinsi "+df_twr['prov'].unique()[0]+"",\
                end=" ", file = f)
        print(", diprediksikan pada tahun 2024 adalah "+df_rank3_2024['jenis_kpi'].values[0]+", "+\
                "menduduki peringkat ke-"+str(min_2024)+" antar provinsi "+df_twr['prov'].unique()[0]+"",\
                end=" ", file = f)
        print("dan pada tahun 2028 adalah "+df_rank3_2028['jenis_kpi'].values[0]+", "+\
                "menduduki peringkat ke-"+str(min_2028)+" antar provinsi "+df_twr['prov'].unique()[0]+".",\
                end=" ", file = f)
        print("", file = f)
        print("", file = f)

    
        for z in df_twr['jenis_kpi'].unique():
            df_twr1 = df_twr.loc[df_twr['kab_name'] == x].copy()
            df_twr1 = df_twr1.loc[df_twr1['jenis_kpi'] == z].copy()
            print("Kabupaten "+x+" di provinsi "+df_twr['prov'].unique()[0]+" memiliki potensi ekonomi berdasarkan pinjaman di sektor "\
                 +z
                 +" sebesar "+str(df_twr1['real_2018'].values[0])+" juta pada tahun 2018, "\
                 +" sebesar "+str(df_twr1['real_2019'].values[0])+" juta pada tahun 2019, "\
                 +" sebesar "+str(df_twr1['real_2020'].values[0])+" juta pada tahun 2020, "\
                 +" sebesar "+str(df_twr1['real_2021'].values[0])+" juta pada tahun 2021, "\
                 +" sebesar "+str(df_twr1['real_2022'].values[0])+" juta pada tahun 2022, "\
                 +" sebesar "+str(df_twr1['real_2022'].values[0])+" juta pada tahun 2023, "\
                 +" dan diprediksi akan sebesar "+str(df_twr1['pred_2024'].values[0])+" juta pada tahun 2024, "\
                 +" sebesar "+str(df_twr1['pred_2025'].values[0])+" juta pada tahun 2025, "\
                 +" sebesar "+str(df_twr1['pred_2026'].values[0])+" juta pada tahun 2026, "\
                 +" sebesar "+str(df_twr1['pred_2027'].values[0])+" juta pada tahun 2027, "\
                 +" sebesar "+str(df_twr1['pred_2028'].values[0])+" juta pada tahun 2028.", end="", file=f)
            print("", file=f)
            print("", file=f)
            print("Untuk potensi ekonomi berdasarkan pinjaman di sektor "+z+" Kabupaten "+x+" dibandingkan dengan seluruh kabupaten di provinsi "+df_twr['prov'].unique()[0]+\
                 " menduduki peringkat ke-"+str(df_twr1['rank_potensi_2023'].values[0])+" pada tahun 2023, dan diprediksikan menduduki peringkat ke-"\
                 +str(df_twr1['rank_potensi_2024'].values[0])+" pada tahun 2024, dan menduduki peringkat ke-"\
                 +str(df_twr1['rank_potensi_2028'].values[0])+" pada tahun 2028.", end=" ", file=f)
            
            print("Dibandingkan dengan potensi ekonomi lainnya, potensi ekonomi berdasarkan pinjaman di sektor "+z+" di kabupaten "+x+" menduduki peringkat ke-"\
                 +str(df_twr1['rank_real_2023'].values[0])+" pada tahun 2023, dan diprediksikan akan menduduki peringkat ke-"\
                 +str(df_twr1['rank_pred_2024'].values[0])+" pada tahun 2024, diprediksikan akan menduduki peringkat ke-"\
                +str(df_twr1['rank_pred_2028'].values[0])+" pada tahun 2028. ", end="", file =f)
                  
            print("Dilihat dari perkembangannya, potensi ekonomi berdasarkan pinjaman di sektor "+z+" di kabupaten "+x+" menduduki peringkat ke-"\
                 +str(df_twr1['rank_growth_2023'].values[0])+" dari tahun 2018 ke tahun 2023, dan diprediksikan akan menduduki peringkat ke-"\
                 +str(df_twr1['rank_growth_2024'].values[0])+" dari tahun 2019 ke tahun 2024, diprediksikan akan menduduki peringkat ke-"\
                +str(df_twr1['rank_growth_2028'].values[0])+" dari tahun 2023 ke tahun 2028. ", end="", file =f)
            print("", file=f)
            print("", file=f)
            
        for z in df_twr2['jenis_simpanan'].unique():
            df_twr1 = df_twr2.loc[df_twr2['kab_name'] == x].copy()
            df_twr1 = df_twr1.loc[df_twr1['jenis_simpanan'] == z].copy()
            print("Kabupaten "+x+" di provinsi "+df_twr['prov'].unique()[0]+" memiliki potensi simpanan sebesar "\
                 +z\
                 +" sebesar "+str(df_twr1['real_2018'].values[0])+" juta pada tahun 2018, "\
                 +" sebesar "+str(df_twr1['real_2019'].values[0])+" juta pada tahun 2019, "\
                 +" sebesar "+str(df_twr1['real_2020'].values[0])+" juta pada tahun 2020, "\
                 +" sebesar "+str(df_twr1['real_2021'].values[0])+" juta pada tahun 2021, "\
                 +" sebesar "+str(df_twr1['real_2022'].values[0])+" juta pada tahun 2022, "\
                 +" sebesar "+str(df_twr1['real_2022'].values[0])+" juta pada tahun 2023, "\
                 +" dan diprediksi akan sebesar "+str(df_twr1['pred_2024'].values[0])+" juta pada tahun 2024, "\
                 +" sebesar "+str(df_twr1['pred_2025'].values[0])+" juta pada tahun 2025, "\
                 +" sebesar "+str(df_twr1['pred_2026'].values[0])+" juta pada tahun 2026, "\
                 +" sebesar "+str(df_twr1['pred_2027'].values[0])+" juta pada tahun 2027, "\
                 +" sebesar "+str(df_twr1['pred_2028'].values[0])+" juta pada tahun 2028.", end="", file=f)
            print("", file=f)
            print("", file=f)
            print("Untuk potensi ekonomi berdasarkan pinjaman di sektor "+z+" Kabupaten "+x+" dibandingkan dengan seluruh kabupaten di provinsi "+df_twr['prov'].unique()[0]+\
                 " menduduki peringkat ke-"+str(df_twr1['rank_potensi_2023'].values[0])+" pada tahun 2023, dan diprediksikan menduduki peringkat ke-"\
                 +str(df_twr1['rank_potensi_2024'].values[0])+" pada tahun 2024, dan menduduki peringkat ke-"\
                 +str(df_twr1['rank_potensi_2028'].values[0])+" pada tahun 2028.", end=" ", file=f)
            
            print("Dibandingkan dengan potensi ekonomi lainnya, potensi ekonomi berdasarkan pinjaman di sektor "+z+" di kabupaten "+x+" menduduki peringkat ke-"\
                 +str(df_twr1['rank_real_2023'].values[0])+" pada tahun 2023, dan diprediksikan akan menduduki peringkat ke-"\
                 +str(df_twr1['rank_pred_2024'].values[0])+" pada tahun 2024, diprediksikan akan menduduki peringkat ke-"\
                +str(df_twr1['rank_pred_2028'].values[0])+" pada tahun 2028. ", end="", file =f)
                  
            print("Dilihat dari perkembangannya, potensi ekonomi berdasarkan pinjaman di sektor "+z+" di kabupaten "+x+" menduduki peringkat ke-"\
                 +str(df_twr1['rank_growth_2023'].values[0])+" dari tahun 2018 ke tahun 2023, dan diprediksikan akan menduduki peringkat ke-"\
                 +str(df_twr1['rank_growth_2024'].values[0])+" dari tahun 2019 ke tahun 2024, diprediksikan akan menduduki peringkat ke-"\
                +str(df_twr1['rank_growth_2028'].values[0])+" dari tahun 2023 ke tahun 2028. ", end="", file =f)
            print("", file=f)
            print("", file=f)
        print("", file=f)

        for z in df_twr3['jenis_kpi'].unique():
            df_twr1 = df_twr3.loc[df_twr3['kab_name'] == x].copy()
            df_twr1 = df_twr1.loc[df_twr1['jenis_kpi'] == z].copy()
            print("Kabupaten "+x+" di provinsi "+df_twr['prov'].unique()[0]+" memiliki potensi simpanan sebesar "\
                 +z\
                 +" sebesar "+str(df_twr1['real_2018'].values[0])+" juta pada tahun 2018, "\
                 +" sebesar "+str(df_twr1['real_2019'].values[0])+" juta pada tahun 2019, "\
                 +" sebesar "+str(df_twr1['real_2020'].values[0])+" juta pada tahun 2020, "\
                 +" sebesar "+str(df_twr1['real_2021'].values[0])+" juta pada tahun 2021, "\
                 +" sebesar "+str(df_twr1['real_2022'].values[0])+" juta pada tahun 2022, "\
                 +" sebesar "+str(df_twr1['real_2022'].values[0])+" juta pada tahun 2023, "\
                 +" dan diprediksi akan sebesar "+str(df_twr1['pred_2024'].values[0])+" juta pada tahun 2024, "\
                 +" sebesar "+str(df_twr1['pred_2025'].values[0])+" juta pada tahun 2025, "\
                 +" sebesar "+str(df_twr1['pred_2026'].values[0])+" juta pada tahun 2026, "\
                 +" sebesar "+str(df_twr1['pred_2027'].values[0])+" juta pada tahun 2027, "\
                 +" sebesar "+str(df_twr1['pred_2028'].values[0])+" juta pada tahun 2028.", end="", file=f)
            print("", file=f)
            print("", file=f)
            print("Untuk potensi ekonomi berdasarkan pinjaman di sektor "+z+" Kabupaten "+x+" dibandingkan dengan seluruh kabupaten di provinsi "+df_twr['prov'].unique()[0]+\
                 " menduduki peringkat ke-"+str(df_twr1['rank_potensi_2023'].values[0])+" pada tahun 2023, dan diprediksikan menduduki peringkat ke-"\
                 +str(df_twr1['rank_potensi_2024'].values[0])+" pada tahun 2024, dan menduduki peringkat ke-"\
                 +str(df_twr1['rank_potensi_2028'].values[0])+" pada tahun 2028.", end=" ", file=f)
            
            print("Dibandingkan dengan potensi ekonomi lainnya, potensi ekonomi berdasarkan pinjaman di sektor "+z+" di kabupaten "+x+" menduduki peringkat ke-"\
                 +str(df_twr1['rank_real_2023'].values[0])+" pada tahun 2023, dan diprediksikan akan menduduki peringkat ke-"\
                 +str(df_twr1['rank_pred_2024'].values[0])+" pada tahun 2024, diprediksikan akan menduduki peringkat ke-"\
                +str(df_twr1['rank_pred_2028'].values[0])+" pada tahun 2028. ", end="", file =f)
                  
            print("Dilihat dari perkembangannya, potensi ekonomi berdasarkan pinjaman di sektor "+z+" di kabupaten "+x+" menduduki peringkat ke-"\
                 +str(df_twr1['rank_growth_2023'].values[0])+" dari tahun 2018 ke tahun 2023, dan diprediksikan akan menduduki peringkat ke-"\
                 +str(df_twr1['rank_growth_2024'].values[0])+" dari tahun 2019 ke tahun 2024, diprediksikan akan menduduki peringkat ke-"\
                +str(df_twr1['rank_growth_2028'].values[0])+" dari tahun 2023 ke tahun 2028. ", end="", file =f)
            print("", file=f)
            print("", file=f)
        print("", file=f)
# Out:
# kutai kartanegara
# berau
# kota pontianak
# kotawaringin barat
# kotawaringin timur
# barito utara
# kota balikpapan
# kota samarinda
# malinau
# bulungan
# nunukan
# kota palangkaraya
# tanah laut
# kotabaru
# banjar
# tapin
# tabalong
# kota tarakan
# sambas
# mempawah
# ketapang
# kapuas hulu
# kubu raya
# kota banjarmasin
# kutai timur
# kapuas
# barito selatan
# katingan
# pulang pisau
# gunung mas
# tana tidung
# barito kuala
# tanah bumbu
# bengkayang
# sintang
# kota banjarbaru
# paser
# kota singkawang
# murung raya
# kota bontang
# sanggau
# kutai barat
# lamandau
# barito timur
# hulu sungai selatan
# hulu sungai utara
# sekadau
# kayong utara
# mahakam ulu
# hulu sungai tengah
# melawi
# penajam paser utara
# sukamara
# seruyan
# balangan
# landak

# %%
unique_counts = len(df_kec['id_nama'].unique())
print(unique_counts)
# Out:
# 626

# %%
#narasi kecamatan
import sys

for x in df_kab_pinjaman['kab_name'].unique():
    print(x,end="-")
    with open('dict/narasi_kec/output_'+x+'_v6.txt', 'w') as f:
        df_twr = df_kab_pinjaman.loc[df_kab_pinjaman['kab_name'] == x].copy()
        df_twr2 = df_kab_simpanan.loc[df_kab_simpanan['kab_name'] == x].copy()
        df_twr3 = df_kab_umkm.loc[df_kab_umkm['kab_name'] == x].copy()
        print("Kabupaten "+x+" adalah kabupaten di provinsi ", end="", file = f)
        print(df_twr['prov'].unique()[0]+".", end=" ", file = f)
        
        min_2023 = df_twr2['rank_potensi_2023'].min()
        df_rank2_2023 = df_twr2.loc[df_twr2['rank_potensi_2023'] == min_2023].copy()
        min_2024 = df_twr2['rank_potensi_2024'].min()
        df_rank2_2024 = df_twr2.loc[df_twr2['rank_potensi_2024'] == min_2024].copy()
        min_2028 = df_twr2['rank_potensi_2028'].min()
        df_rank2_2028 = df_twr2.loc[df_twr2['rank_potensi_2028'] == min_2028].copy()
        print("Potensi simpanan di kabupaten "+x+" pada tahun 2023 adalah "+df_rank2_2023['jenis_simpanan'].values[0]+", "+\
              "menduduki peringkat ke-"+str(min_2023)+" antar provinsi "+df_twr['prov'].unique()[0]+".",\
                end=" ", file = f)
        
        
        min_2023 = df_twr['rank_potensi_2023'].min()
        df_rank1_2023 = df_twr.loc[df_twr['rank_potensi_2023'] == min_2023].copy()
        min_2024 = df_twr['rank_potensi_2024'].min()
        df_rank1_2024 = df_twr.loc[df_twr['rank_potensi_2024'] == min_2024].copy()
        min_2028 = df_twr['rank_potensi_2028'].min()
        df_rank1_2028 = df_twr.loc[df_twr['rank_potensi_2028'] == min_2028].copy()
                
        print("Potensi sektor ekonomi terbaik di kabupaten "+x+" pada tahun 2023 adalah "+df_rank1_2023['jenis_kpi'].values[0]+", "+\
              "menduduki peringkat ke-"+str(min_2023)+" antar provinsi "+df_twr['prov'].unique()[0]+"",\
                end=",", file = f)
        print(" prediksi tahun 2024 adalah "+df_rank1_2024['jenis_kpi'].values[0]+", "+\
                "menduduki peringkat ke-"+str(min_2024)+" antar provinsi "+df_twr['prov'].unique()[0]+"",\
                end=",", file = f)
        print(" dan prediksi pada tahun 2028 adalah "+df_rank1_2028['jenis_kpi'].values[0]+", "+\
                "menduduki peringkat ke-"+str(min_2028)+" antar provinsi "+df_twr['prov'].unique()[0]+".",\
                end=" ", file = f)
        
        min_2023 = df_twr3['rank_potensi_2023'].min()
        df_rank3_2023 = df_twr3.loc[df_twr3['rank_potensi_2023'] == min_2023].copy()
        min_2024 = df_twr3['rank_potensi_2024'].min()
        df_rank3_2024 = df_twr3.loc[df_twr3['rank_potensi_2024'] == min_2024].copy()
        min_2028 = df_twr3['rank_potensi_2028'].min()
        df_rank3_2028 = df_twr3.loc[df_twr3['rank_potensi_2028'] == min_2028].copy()
                
        print("Potensi sektor UMKM terbaik di kabupaten "+x+" pada tahun 2023 adalah "+df_rank3_2023['jenis_kpi'].values[0]+", "+\
              "menduduki peringkat ke-"+str(min_2023)+" antar provinsi "+df_twr['prov'].unique()[0]+"",\
                end=" ", file = f)
        print(", diprediksikan pada tahun 2024 adalah "+df_rank3_2024['jenis_kpi'].values[0]+", "+\
                "menduduki peringkat ke-"+str(min_2024)+" antar provinsi "+df_twr['prov'].unique()[0]+"",\
                end=" ", file = f)
        print("dan pada tahun 2028 adalah "+df_rank3_2028['jenis_kpi'].values[0]+", "+\
                "menduduki peringkat ke-"+str(min_2028)+" antar provinsi "+df_twr['prov'].unique()[0]+".",\
                end="", file = f)
        print("", file = f)
        print("", file = f)


        for z in df_twr['jenis_kpi'].unique():
                df_twr1 = df_twr.loc[df_twr['kab_name'] == x].copy()
                df_twr1 = df_twr1.loc[df_twr1['jenis_kpi'] == z].copy()
                print("Kabupaten "+x+" di provinsi "+df_twr['prov'].unique()[0]+" memiliki potensi ekonomi berdasarkan pinjaman di sektor "\
                     +z+" sebesar "+str(df_twr1['real_2017'].values[0])+" juta pada tahun 2017, "\
                     +" sebesar "+str(df_twr1['real_2018'].values[0])+" juta pada tahun 2018, "\
                     +" sebesar "+str(df_twr1['real_2019'].values[0])+" juta pada tahun 2019, "\
                     +" sebesar "+str(df_twr1['real_2020'].values[0])+" juta pada tahun 2020, "\
                     +" sebesar "+str(df_twr1['real_2021'].values[0])+" juta pada tahun 2021, "\
                     +" sebesar "+str(df_twr1['real_2022'].values[0])+" juta pada tahun 2022, "\
                     +" sebesar "+str(df_twr1['real_2022'].values[0])+" juta pada tahun 2023, "\
                     +" dan diprediksi akan sebesar "+str(df_twr1['pred_2024'].values[0])+" juta pada tahun 2024, "\
                     +" sebesar "+str(df_twr1['pred_2025'].values[0])+" juta pada tahun 2025, "\
                     +" sebesar "+str(df_twr1['pred_2026'].values[0])+" juta pada tahun 2026, "\
                     +" sebesar "+str(df_twr1['pred_2027'].values[0])+" juta pada tahun 2027, "\
                     +" sebesar "+str(df_twr1['pred_2028'].values[0])+" juta pada tahun 2028.", end="",file = f)
                print("", file=f)
                print("", file=f)
                print("Untuk potensi ekonomi berdasarkan pinjaman di sektor "+z+" Kabupaten "+x+" dibandingkan dengan seluruh kabupaten di provinsi "+df_twr['prov'].unique()[0]+\
                     " menduduki peringkat ke-"+str(df_twr1['rank_potensi_2023'].values[0])+" pada tahun 2023, dan diprediksikan menduduki peringkat ke-"\
                     +str(df_twr1['rank_potensi_2024'].values[0])+" pada tahun 2024, dan menduduki peringkat ke-"\
                     +str(df_twr1['rank_potensi_2028'].values[0])+" pada tahun 2028.", end=" ",file = f)

                print("Dibandingkan dengan potensi ekonomi lainnya, potensi ekonomi berdasarkan pinjaman di sektor "+z+" di kabupaten "+x+" menduduki peringkat ke-"\
                     +str(df_twr1['rank_real_2023'].values[0])+" pada tahun 2023, dan diprediksikan akan menduduki peringkat ke-"\
                     +str(df_twr1['rank_pred_2024'].values[0])+" pada tahun 2024, diprediksikan akan menduduki peringkat ke-"\
                    +str(df_twr1['rank_pred_2028'].values[0])+" pada tahun 2028. ", end="",file = f)

                print("Dilihat dari perkembangannya, potensi ekonomi berdasarkan pinjaman di sektor "+z+" di kabupaten "+x+" menduduki peringkat ke-"\
                     +str(df_twr1['rank_growth_2023'].values[0])+" dari tahun 2018 ke tahun 2023, dan diprediksikan akan menduduki peringkat ke-"\
                     +str(df_twr1['rank_growth_2024'].values[0])+" dari tahun 2019 ke tahun 2024, diprediksikan akan menduduki peringkat ke-"\
                    +str(df_twr1['rank_growth_2028'].values[0])+" dari tahun 2023 ke tahun 2028. ", end="",file = f)
                print("",file = f)
                print("",file = f)

        
        
        for z in df_twr2['jenis_simpanan'].unique():
            df_twr1 = df_twr2.loc[df_twr2['kab_name'] == x].copy()
            df_twr1 = df_twr1.loc[df_twr1['jenis_simpanan'] == z].copy()
            print("Kabupaten "+x+" di provinsi "+df_twr['prov'].unique()[0]+" memiliki potensi simpanan sebesar "\
                 +z\
                 +" sebesar "+str(df_twr1['real_2018'].values[0])+" juta pada tahun 2018, "\
                 +" sebesar "+str(df_twr1['real_2019'].values[0])+" juta pada tahun 2019, "\
                 +" sebesar "+str(df_twr1['real_2020'].values[0])+" juta pada tahun 2020, "\
                 +" sebesar "+str(df_twr1['real_2021'].values[0])+" juta pada tahun 2021, "\
                 +" sebesar "+str(df_twr1['real_2022'].values[0])+" juta pada tahun 2022, "\
                 +" sebesar "+str(df_twr1['real_2022'].values[0])+" juta pada tahun 2023, "\
                 +" dan diprediksi akan sebesar "+str(df_twr1['pred_2024'].values[0])+" juta pada tahun 2024, "\
                 +" sebesar "+str(df_twr1['pred_2025'].values[0])+" juta pada tahun 2025, "\
                 +" sebesar "+str(df_twr1['pred_2026'].values[0])+" juta pada tahun 2026, "\
                 +" sebesar "+str(df_twr1['pred_2027'].values[0])+" juta pada tahun 2027, "\
                 +" sebesar "+str(df_twr1['pred_2028'].values[0])+" juta pada tahun 2028.", end="", file=f)
            print("", file=f)
            print("", file=f)
            print("Untuk potensi simpanan "+z+" Kabupaten "+x+" dibandingkan dengan seluruh kabupaten di provinsi "+df_twr['prov'].unique()[0]+\
                 " menduduki peringkat ke-"+str(df_twr1['rank_potensi_2023'].values[0])+" pada tahun 2023, dan diprediksikan menduduki peringkat ke-"\
                 +str(df_twr1['rank_potensi_2024'].values[0])+" pada tahun 2024, dan menduduki peringkat ke-"\
                 +str(df_twr1['rank_potensi_2028'].values[0])+" pada tahun 2028.", end=" ", file=f)
            
            print("Dibandingkan dengan potensi ekonomi lainnya, potensi simpanan "+z+" di kabupaten "+x+" menduduki peringkat ke-"\
                 +str(df_twr1['rank_real_2023'].values[0])+" pada tahun 2023, dan diprediksikan akan menduduki peringkat ke-"\
                 +str(df_twr1['rank_pred_2024'].values[0])+" pada tahun 2024, diprediksikan akan menduduki peringkat ke-"\
                +str(df_twr1['rank_pred_2028'].values[0])+" pada tahun 2028. ", end="", file =f)
                  
            print("Dilihat dari perkembangannya, potensi simpanan "+z+" di kabupaten "+x+" menduduki peringkat ke-"\
                 +str(df_twr1['rank_growth_2023'].values[0])+" dari tahun 2018 ke tahun 2023, dan diprediksikan akan menduduki peringkat ke-"\
                 +str(df_twr1['rank_growth_2024'].values[0])+" dari tahun 2019 ke tahun 2024, diprediksikan akan menduduki peringkat ke-"\
                +str(df_twr1['rank_growth_2028'].values[0])+" dari tahun 2023 ke tahun 2028. ", end="", file =f)
            print("", file=f)
            print("", file=f)
        

        for z in df_twr3['jenis_kpi'].unique():
            df_twr1 = df_twr3.loc[df_twr3['kab_name'] == x].copy()
            df_twr1 = df_twr1.loc[df_twr1['jenis_kpi'] == z].copy()
            print("Kabupaten "+x+" di provinsi "+df_twr['prov'].unique()[0]+" memiliki potensi UMKM sebesar "\
                 +z\
                 +" sebesar "+str(df_twr1['real_2018'].values[0])+" juta pada tahun 2018, "\
                 +" sebesar "+str(df_twr1['real_2019'].values[0])+" juta pada tahun 2019, "\
                 +" sebesar "+str(df_twr1['real_2020'].values[0])+" juta pada tahun 2020, "\
                 +" sebesar "+str(df_twr1['real_2021'].values[0])+" juta pada tahun 2021, "\
                 +" sebesar "+str(df_twr1['real_2022'].values[0])+" juta pada tahun 2022, "\
                 +" sebesar "+str(df_twr1['real_2022'].values[0])+" juta pada tahun 2023, "\
                 +" dan diprediksi akan sebesar "+str(df_twr1['pred_2024'].values[0])+" juta pada tahun 2024, "\
                 +" sebesar "+str(df_twr1['pred_2025'].values[0])+" juta pada tahun 2025, "\
                 +" sebesar "+str(df_twr1['pred_2026'].values[0])+" juta pada tahun 2026, "\
                 +" sebesar "+str(df_twr1['pred_2027'].values[0])+" juta pada tahun 2027, "\
                 +" sebesar "+str(df_twr1['pred_2028'].values[0])+" juta pada tahun 2028.", end="", file=f)
            print("", file=f)
            print("", file=f)
            print("Untuk potensi UMKM di sektor "+z+" Kabupaten "+x+" dibandingkan dengan seluruh kabupaten di provinsi "+df_twr['prov'].unique()[0]+\
                 " menduduki peringkat ke-"+str(df_twr1['rank_potensi_2023'].values[0])+" pada tahun 2023, dan diprediksikan menduduki peringkat ke-"\
                 +str(df_twr1['rank_potensi_2024'].values[0])+" pada tahun 2024, dan menduduki peringkat ke-"\
                 +str(df_twr1['rank_potensi_2028'].values[0])+" pada tahun 2028.", end=" ", file=f)
            
            print("Dibandingkan dengan UMKM lainnya, potensi UMKM di sektor "+z+" di kabupaten "+x+" menduduki peringkat ke-"\
                 +str(df_twr1['rank_real_2023'].values[0])+" pada tahun 2023, dan diprediksikan akan menduduki peringkat ke-"\
                 +str(df_twr1['rank_pred_2024'].values[0])+" pada tahun 2024, diprediksikan akan menduduki peringkat ke-"\
                +str(df_twr1['rank_pred_2028'].values[0])+" pada tahun 2028. ", end="", file =f)
                  
            print("Dilihat dari perkembangannya, potensi UMKM di sektor "+z+" di kabupaten "+x+" menduduki peringkat ke-"\
                 +str(df_twr1['rank_growth_2023'].values[0])+" dari tahun 2018 ke tahun 2023, dan diprediksikan akan menduduki peringkat ke-"\
                 +str(df_twr1['rank_growth_2024'].values[0])+" dari tahun 2019 ke tahun 2024, diprediksikan akan menduduki peringkat ke-"\
                +str(df_twr1['rank_growth_2028'].values[0])+" dari tahun 2023 ke tahun 2028. ", end="", file =f)
            print("", file=f)
            print("", file=f)
       

        df_twr_kec = df_kec_simpanan.loc[df_kec_simpanan['kab_name'] == x].copy()
        for xx in df_twr_kec['id_nama'].unique():
        
            df_twr2 = df_kec_pinjaman.loc[df_kec_pinjaman['id_nama'] == xx].copy()
            df_twr4 = df_kec_simpanan.loc[df_kec_simpanan['id_nama'] == xx].copy()
            df_twr5 = df_kec_umkm.loc[df_kec_umkm['id_nama'] == xx].copy()
            
            print(df_twr2['kec_name'].unique()[0]+" adalah kecamatan di kabupaten "+x+" di provinsi "\
                  +df_twr2['prov_name'].unique()[0]+".", end=" ",file = f)
            
            min_2023 = df_twr4['rank_potensi_2023'].min()
            df_rank2_2023 = df_twr4.loc[df_twr4['rank_potensi_2023'] == min_2023].copy()
            min_2024 = df_twr4['rank_potensi_2024'].min()
            df_rank2_2024 = df_twr4.loc[df_twr4['rank_potensi_2024'] == min_2024].copy()
            min_2028 = df_twr4['rank_potensi_2028'].min()
            df_rank2_2028 = df_twr4.loc[df_twr4['rank_potensi_2028'] == min_2028].copy()
            print("Potensi simpanan di kecamatan "+xx+" pada tahun 2023 adalah "+df_rank2_2023['jenis_simpanan'].values[0]+", "+\
              "menduduki peringkat ke-"+str(min_2023)+" antar provinsi "+df_twr['prov'].unique()[0]+".",\
                end=" ", file = f)

            
            min_2023 = df_twr2['rank_potensi_2023'].min()
            df_rank1_2023 = df_twr2.loc[df_twr2['rank_potensi_2023'] == min_2023].copy()
            min_2024 = df_twr2['rank_potensi_2024'].min()
            df_rank1_2024 = df_twr2.loc[df_twr2['rank_potensi_2024'] == min_2024].copy()
            min_2028 = df_twr2['rank_potensi_2028'].min()
            df_rank1_2028 = df_twr2.loc[df_twr2['rank_potensi_2028'] == min_2028].copy()

            print("Potensi sektor ekonomi terbaik di kecamatan "+xx+" pada tahun 2023 adalah "+df_rank1_2023['jenis_kpi'].values[0]+", "+\
                  "menduduki peringkat ke-"+str(min_2023)+" antar provinsi "+df_twr['prov'].unique()[0]+"",\
                    end=",", file = f)
            print(" prediksi tahun 2024 adalah "+df_rank1_2024['jenis_kpi'].values[0]+", "+\
                    "menduduki peringkat ke-"+str(min_2024)+" antar provinsi "+df_twr['prov'].unique()[0]+"",\
                    end=",", file = f)
            print(" dan prediksi pada tahun 2028 adalah "+df_rank1_2028['jenis_kpi'].values[0]+", "+\
                    "menduduki peringkat ke-"+str(min_2028)+" antar provinsi "+df_twr['prov'].unique()[0]+".",\
                    end=" ", file = f)

            min_2023 = df_twr5['rank_potensi_2023'].min()
            df_rank3_2023 = df_twr5.loc[df_twr5['rank_potensi_2023'] == min_2023].copy()
            min_2024 = df_twr5['rank_potensi_2024'].min()
            df_rank3_2024 = df_twr5.loc[df_twr5['rank_potensi_2024'] == min_2024].copy()
            min_2028 = df_twr5['rank_potensi_2028'].min()
            df_rank3_2028 = df_twr5.loc[df_twr5['rank_potensi_2028'] == min_2028].copy()

            print("Potensi sektor UMKM terbaik di kecamatan "+xx+" pada tahun 2023 adalah "+df_rank3_2023['jenis_kpi'].values[0]+", "+\
                  "menduduki peringkat ke-"+str(min_2023)+" antar provinsi "+df_twr['prov'].unique()[0]+"",\
                    end=" ", file = f)
            print(", diprediksikan pada tahun 2024 adalah "+df_rank3_2024['jenis_kpi'].values[0]+", "+\
                    "menduduki peringkat ke-"+str(min_2024)+" antar provinsi "+df_twr['prov'].unique()[0]+"",\
                    end=" ", file = f)
            print("dan pada tahun 2028 adalah "+df_rank3_2028['jenis_kpi'].values[0]+", "+\
                    "menduduki peringkat ke-"+str(min_2028)+" antar provinsi "+df_twr['prov'].unique()[0]+".",\
                    end=" ", file = f)
            print("", file = f)
            print("", file = f)
            
            
            for zz in df_twr2['jenis_kpi'].unique():
                df_twr3 = df_twr2.loc[df_twr2['id_nama'] == xx].copy()
                df_twr3 = df_twr3.loc[df_twr3['jenis_kpi'] == zz].copy()

                print("Kecamatan " +df_twr3['kec_name'].unique()[0]+" dari Kabupaten "+x+" di provinsi "+df_twr3['prov_name'].unique()[0]+" diprediksikan memiliki potensi ekonomi berdasarkan pinjaman di sektor "\
                     +zz\
                     +" sebesar "+str(df_twr3['pred_2018'].values[0])+" juta pada tahun 2018, "\
                     +" sebesar "+str(df_twr3['pred_2019'].values[0])+" juta pada tahun 2019, "\
                     +" sebesar "+str(df_twr3['pred_2020'].values[0])+" juta pada tahun 2020, "\
                     +" sebesar "+str(df_twr3['pred_2021'].values[0])+" juta pada tahun 2021, "\
                     +" sebesar "+str(df_twr3['pred_2022'].values[0])+" juta pada tahun 2022, "\
                     +" sebesar "+str(df_twr3['pred_2022'].values[0])+" juta pada tahun 2023, "\
                     +" sebesar "+str(df_twr3['pred_2024'].values[0])+" juta pada tahun 2024, "\
                     +" sebesar "+str(df_twr3['pred_2025'].values[0])+" juta pada tahun 2025, "\
                     +" sebesar "+str(df_twr3['pred_2026'].values[0])+" juta pada tahun 2026, "\
                     +" sebesar "+str(df_twr3['pred_2027'].values[0])+" juta pada tahun 2027, "\
                     +" sebesar "+str(df_twr3['pred_2028'].values[0])+" juta pada tahun 2028.", end="",file = f)
                print("", file=f)
                print("", file=f)
                print("Untuk potensi ekonomi berdasarkan pinjaman di sektor "+zz+" kecamatan "+df_twr3['kec_name'].unique()[0]+" dibandingkan dengan seluruh kecamatan di kabupaten "+df_twr3['kab_name'].unique()[0]+\
                     " diprediksikan menduduki peringkat ke-"+str(df_twr3['rank_potensi_2023'].values[0])+" pada tahun 2023, dan diprediksikan menduduki peringkat ke-"\
                     +str(df_twr3['rank_potensi_2024'].values[0])+" pada tahun 2024, dan menduduki peringkat ke-"\
                     +str(df_twr3['rank_potensi_2028'].values[0])+" pada tahun 2028.", end=" ",file = f)

                print("Dibandingkan dengan potensi ekonomi lainnya antar kecamatan di kabupaten "+x+", potensi ekonomi berdasarkan pinjaman di sektor "+zz+" di kecamatan "+df_twr3['kec_name'].unique()[0]+" diprediksikan menduduki peringkat ke-"\
                     +str(df_twr3['rank_pred_2023_kab'].values[0])+" pada tahun 2023, dan diprediksikan akan menduduki peringkat ke-"\
                     +str(df_twr3['rank_pred_2024_kab'].values[0])+" pada tahun 2024, diprediksikan akan menduduki peringkat ke-"\
                    +str(df_twr3['rank_pred_2028_kab'].values[0])+" pada tahun 2028. ", end="",file = f)

                print("Dilihat dari perkembangan antar kecamatan di kabupaten "+x+", potensi ekonomi berdasarkan pinjaman di sektor "+zz+" di kecamatan "+df_twr3['kec_name'].unique()[0]+" diprediksikan menduduki peringkat ke-"\
                     +str(df_twr3['rank_growth_2023_kab'].values[0])+" dari tahun 2018 ke tahun 2023, dan diprediksikan akan menduduki peringkat ke-"\
                     +str(df_twr3['rank_growth_2024_kab'].values[0])+" dari tahun 2019 ke tahun 2024, diprediksikan akan menduduki peringkat ke-"\
                    +str(df_twr3['rank_growth_2028_kab'].values[0])+" dari tahun 2023 ke tahun 2028. ", end="",file = f)
                print("",file = f)
                print("",file = f)
                
            for zz in df_twr4['jenis_simpanan'].unique():
                df_twr6 = df_twr4.loc[df_twr4['id_nama'] == xx].copy()
                df_twr6 = df_twr6.loc[df_twr6['jenis_simpanan'] == zz].copy()

                print("Kecamatan " +df_twr6['kec_name'].unique()[0]+" dari Kabupaten "+x+" di provinsi "+\
                      df_twr6['prov_name'].unique()[0]+" diprediksikan memiliki potensi simpanan "\
                     +zz\
                     +" sebesar "+str(df_twr6['pred_2018'].values[0])+" juta pada tahun 2018, "\
                     +" sebesar "+str(df_twr6['pred_2019'].values[0])+" juta pada tahun 2019, "\
                     +" sebesar "+str(df_twr6['pred_2020'].values[0])+" juta pada tahun 2020, "\
                     +" sebesar "+str(df_twr6['pred_2021'].values[0])+" juta pada tahun 2021, "\
                     +" sebesar "+str(df_twr6['pred_2022'].values[0])+" juta pada tahun 2022, "\
                     +" sebesar "+str(df_twr6['pred_2022'].values[0])+" juta pada tahun 2023, "\
                     +" sebesar "+str(df_twr6['pred_2024'].values[0])+" juta pada tahun 2024, "\
                     +" sebesar "+str(df_twr6['pred_2025'].values[0])+" juta pada tahun 2025, "\
                     +" sebesar "+str(df_twr6['pred_2026'].values[0])+" juta pada tahun 2026, "\
                     +" sebesar "+str(df_twr6['pred_2027'].values[0])+" juta pada tahun 2027, "\
                     +" sebesar "+str(df_twr6['pred_2028'].values[0])+" juta pada tahun 2028.", end="",file = f)
                print("", file=f)
                print("", file=f)
                print("Untuk simpanan "+zz+" kecamatan "+df_twr6['kec_name'].unique()[0]+" dibandingkan dengan seluruh kecamatan di kabupaten "+df_twr6['kab_name'].unique()[0]+\
                     " diprediksikan menduduki peringkat ke-"+str(df_twr6['rank_potensi_2023'].values[0])+" pada tahun 2023, dan diprediksikan menduduki peringkat ke-"\
                     +str(df_twr6['rank_potensi_2024'].values[0])+" pada tahun 2024, dan menduduki peringkat ke-"\
                     +str(df_twr6['rank_potensi_2028'].values[0])+" pada tahun 2028.", end=" ",file = f)

                print("Dibandingkan dengan potensi simpanan lainnya antar kecamatan di kabupaten "+x+", potensi simpanan "+zz+" di kecamatan "+df_twr6['kec_name'].unique()[0]+" diprediksikan menduduki peringkat ke-"\
                     +str(df_twr6['rank_pred_2023_kab'].values[0])+" pada tahun 2023, dan diprediksikan akan menduduki peringkat ke-"\
                     +str(df_twr6['rank_pred_2024_kab'].values[0])+" pada tahun 2024, diprediksikan akan menduduki peringkat ke-"\
                    +str(df_twr6['rank_pred_2028_kab'].values[0])+" pada tahun 2028. ", end="",file = f)

                print("Dilihat dari perkembangan antar kecamatan di kabupaten "+x+", potensi simpanan "+zz+" di kecamatan "+df_twr6['kec_name'].unique()[0]+" diprediksikan menduduki peringkat ke-"\
                     +str(df_twr6['rank_growth_2023_kab'].values[0])+" dari tahun 2018 ke tahun 2023, dan diprediksikan akan menduduki peringkat ke-"\
                     +str(df_twr6['rank_growth_2024_kab'].values[0])+" dari tahun 2019 ke tahun 2024, diprediksikan akan menduduki peringkat ke-"\
                    +str(df_twr6['rank_growth_2028_kab'].values[0])+" dari tahun 2023 ke tahun 2028. ", end="",file = f)
                print("",file = f)
                print("",file = f)
                
            for zz in df_twr5['jenis_kpi'].unique():
                df_twr7 = df_twr5.loc[df_twr5['id_nama'] == xx].copy()
                df_twr7 = df_twr7.loc[df_twr7['jenis_kpi'] == zz].copy()

                print("Kecamatan " +df_twr6['kec_name'].unique()[0]+" dari Kabupaten "+x+" di provinsi "+\
                      df_twr6['prov_name'].unique()[0]+" diprediksikan memiliki potensi UMKM "\
                     +zz\
                     +" sebesar "+str(df_twr7['pred_2018'].values[0])+" juta pada tahun 2018, "\
                     +" sebesar "+str(df_twr7['pred_2019'].values[0])+" juta pada tahun 2019, "\
                     +" sebesar "+str(df_twr7['pred_2020'].values[0])+" juta pada tahun 2020, "\
                     +" sebesar "+str(df_twr7['pred_2021'].values[0])+" juta pada tahun 2021, "\
                     +" sebesar "+str(df_twr7['pred_2022'].values[0])+" juta pada tahun 2022, "\
                     +" sebesar "+str(df_twr7['pred_2022'].values[0])+" juta pada tahun 2023, "\
                     +" sebesar "+str(df_twr7['pred_2024'].values[0])+" juta pada tahun 2024, "\
                     +" sebesar "+str(df_twr7['pred_2025'].values[0])+" juta pada tahun 2025, "\
                     +" sebesar "+str(df_twr7['pred_2026'].values[0])+" juta pada tahun 2026, "\
                     +" sebesar "+str(df_twr7['pred_2027'].values[0])+" juta pada tahun 2027, "\
                     +" sebesar "+str(df_twr7['pred_2028'].values[0])+" juta pada tahun 2028.", end="",file = f)
                print("", file=f)
                print("", file=f)
                print("Untuk UMKM sektor "+zz+" kecamatan "+df_twr7['kec_name'].unique()[0]+" dibandingkan dengan seluruh kecamatan di kabupaten "+df_twr7['kab_name'].unique()[0]+\
                     " diprediksikan menduduki peringkat ke-"+str(df_twr7['rank_potensi_2023'].values[0])+" pada tahun 2023, dan diprediksikan menduduki peringkat ke-"\
                     +str(df_twr7['rank_potensi_2024'].values[0])+" pada tahun 2024, dan menduduki peringkat ke-"\
                     +str(df_twr7['rank_potensi_2028'].values[0])+" pada tahun 2028.", end=" ",file = f)

                print("Dibandingkan dengan potensi UMKM lainnya antar kecamatan di kabupaten "+x+", potensi UMKM di sektor "+zz+" di kecamatan "+df_twr7['kec_name'].unique()[0]+" diprediksikan menduduki peringkat ke-"\
                     +str(df_twr7['rank_pred_2023_kab'].values[0])+" pada tahun 2023, dan diprediksikan akan menduduki peringkat ke-"\
                     +str(df_twr7['rank_pred_2024_kab'].values[0])+" pada tahun 2024, diprediksikan akan menduduki peringkat ke-"\
                    +str(df_twr7['rank_pred_2028_kab'].values[0])+" pada tahun 2028. ", end="",file = f)

                print("Dilihat dari perkembangan antar kecamatan di kabupaten "+x+", potensi UMKM di sektor "+zz+" di kecamatan "+df_twr7['kec_name'].unique()[0]+" diprediksikan menduduki peringkat ke-"\
                     +str(df_twr7['rank_growth_2023_kab'].values[0])+" dari tahun 2018 ke tahun 2023, dan diprediksikan akan menduduki peringkat ke-"\
                     +str(df_twr7['rank_growth_2024_kab'].values[0])+" dari tahun 2019 ke tahun 2024, diprediksikan akan menduduki peringkat ke-"\
                    +str(df_twr7['rank_growth_2028_kab'].values[0])+" dari tahun 2023 ke tahun 2028. ", end="",file = f)
                print("",file = f)
                print("",file = f)
                
    print(x+" done")
# Out:
# kutai kartanegara-kutai kartanegara done
# berau-berau done
# kota pontianak-kota pontianak done
# kotawaringin barat-kotawaringin barat done
# kotawaringin timur-kotawaringin timur done
# barito utara-barito utara done
# kota balikpapan-kota balikpapan done
# kota samarinda-kota samarinda done
# malinau-malinau done
# bulungan-bulungan done
# nunukan-nunukan done
# kota palangkaraya-kota palangkaraya done
# tanah laut-tanah laut done
# kotabaru-kotabaru done
# banjar-banjar done
# tapin-tapin done
# tabalong-tabalong done
# kota tarakan-kota tarakan done
# sambas-sambas done
# mempawah-mempawah done
# ketapang-ketapang done
# kapuas hulu-kapuas hulu done
# kubu raya-kubu raya done
# kota banjarmasin-kota banjarmasin done
# kutai timur-kutai timur done
# kapuas-kapuas done
# barito selatan-barito selatan done
# katingan-katingan done
# pulang pisau-pulang pisau done
# gunung mas-gunung mas done
# tana tidung-tana tidung done
# barito kuala-barito kuala done
# ...

# %%
df_twr = df_kab_pinjaman.loc[df_kab_pinjaman['kab_name'] == "donggala"].copy()
df_twr
# Out:
# Empty DataFrame
# Columns: [prov, kab_name, kab_id, jenis_sektor_ekonomi, jenis_kpi, real_2017, real_2018, real_2019, real_2020, real_2021, real_2022, real_2023, pred_2024, pred_2025, pred_2026, pred_2027, pred_2028, rank_real_2023, rank_growth_2023, rank_pred_2024, rank_growth_2024, rank_pred_2028, rank_growth_2028, rank_potensi_2023, rank_potensi_2024, rank_potensi_2025, rank_potensi_2028]
# Index: []
#
# [0 rows x 27 columns]

# %%
print("done")
# Out:
# done
